# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Admin\\Downloads\\sal.csv")
df
# Out:
#     Year  Salary
# 0    1.1   39343
# 1    1.3   46205
# 2    1.5   37731
# 3    2.0   43525
# 4    2.2   39891
# 5    2.9   56642
# 6    3.0   60150
# 7    3.2   54445
# 8    3.2   64445
# 9    3.7   57189
# 10   3.9   63218
# 11   4.0   55794
# 12   4.0   56957
# 13   4.1   57081
# 14   4.5   61111
# 15   4.9   67938
# 16   5.1   66029
# 17   5.3   83088
# 18   5.9   81363
# 19   6.0   93940
# 20   6.8   91738
# 21   7.1   98273
# 22   7.9  101302
# 23   8.2  113812
# 24   8.7  109431
# 25   9.0  105582
# 26   9.5  116969
# 27   9.6  112635
# 28  10.3  122391
# 29  10.5  121872
# 30  11.2  127345
# 31  11.5  126756
# 32  12.3  128765
# 33  12.9  135675
# 34  13.5  139465

# %%
# %matplotlib inline
plt.xlabel("Year(numbers)")
plt.ylabel("Salary(US$)")
plt.scatter(df.Year,df.Salary,color='red')

# %%
x=df.Year.values.reshape(-1,1)
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]])

# %%
y=df.Salary.values.reshape(-1,1)
y
# Out:
# array([[ 39343],
#        [ 46205],
#        [ 37731],
#        [ 43525],
#        [ 39891],
#        [ 56642],
#        [ 60150],
#        [ 54445],
#        [ 64445],
#        [ 57189],
#        [ 63218],
#        [ 55794],
#        [ 56957],
#        [ 57081],
#        [ 61111],
#        [ 67938],
#        [ 66029],
#        [ 83088],
#        [ 81363],
#        [ 93940],
#        [ 91738],
#        [ 98273],
#        [101302],
#        [113812],
#        [109431],
#        [105582],
#        [116969],
#        [112635],
#        [122391],
#        [121872],
#        [127345],
#        [126756],
#        [128765],
#        [135675],
#        [139465]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_split=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x,regressor.predict(x),color='blue')

# %%
salary=regressor.predict([[9.0]])
print(int(salary))
plt.scatter(x,y,color='red')
plt.plot(x,regressor.predict(x),color='blue')
plt.scatter(7.0,salary,color='green')
# Out:
# 106238
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24436\210591862.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(int(salary))

# %%
regressor.score(x_train,y_train)
# Out:
# 0.9759668652528644
